# %%
import pandas as pd
data = {
    'day':['1/1/2018','2/1/2018','3/1/2018','4/1/2018'],
    'temperature':[35,28,18,20],
    'event':['rain','sunny','rain','sunny']
}
df=pd.DataFrame(data)
df
# Out:
#         day  event  temperature
# 0  1/1/2018   rain           35
# 1  2/1/2018  sunny           28
# 2  3/1/2018   rain           18
# 3  4/1/2018  sunny           20

# %%
import pandas as pd
df = pd.read_csv('Data.csv')
new_df=df.interpolate()
new_df
# Out:
#          Day     Province  Temperature  WindSpeed  Event
# 0   1/1/2018      Kalasin         35.0       10.0  Sunny
# 1   2/1/2018      Bangkok         30.0       10.0   Rain
# 2   3/1/2018       Rayong         17.5       15.0    NaN
# 3   4/1/2018     Chonburi          5.0       20.0   Snow
# 4   5/1/2018          Nan         12.0       20.0   Snow
# 5   6/1/2018         Trat         22.0       20.0    NaN
# 6   7/1/2018          Pae         32.0       20.0   Rain
# 7   8/1/2018   Chiang mai         33.0       30.0   Rain
# 8   9/1/2018  Chanthaburi          4.0       50.0   Rain
# 9  10/1/2018         Nost         56.0       60.0  Sunny

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/cpu-performance/machine.data')
df.head()
# Out:
#   adviser    32/60  125   256   6000  256.1  16  128  198  199
# 0  amdahl   470v/7   29  8000  32000     32   8   32  269  253
# 1  amdahl  470v/7a   29  8000  32000     32   8   32  220  253
# 2  amdahl  470v/7b   29  8000  32000     32   8   32  172  253
# 3  amdahl  470v/7c   29  8000  16000     32   8   16  132  132
# 4  amdahl   470v/b   26  8000  32000     64   8   32  318  290

# %%
df.plot();
